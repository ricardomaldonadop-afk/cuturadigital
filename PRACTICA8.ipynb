# %%
var = 2
print("selecciona una opcion /n 1suma 2resta 3multiplicacion 4dividir 5salir ")
vaar =input ("")
if (var == "1"):
  var1=int(input("dame un numero")
  var2=int(inpu("dame oto numero"))
  print("var1+var2")
elif(var == "2")
var1=int(input("dame un numero")
var2=int(input("dame otro numero")
print(var1 = var2)
elif(var == "3")
var=int(input("dame un numero")
var=int(input("dame orto numero")
prit(var1 * var2)
elif(var == "4")
var1=int(input("dame un numero")
var2=in(/input("dame otro numero")
print(var1/var2)
# Out:
#   File "/tmp/ipython-input-2562243178.py", line 5
#     var1=int(input("dame un numero")
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
